# %%
import base64
import requests
import datetime
from urllib.parse import urlencode

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
        
    
    def get_client_credentials(self):
        """
        Return a base64 encoded string
        """        
        client_id = self.client_id
        client_secret = self.client_secret
        if (client_id == None or client_secret == None):
            raise Exception("Set client_id and client_server.")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
        
        
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {"Authorization":f"Basic {client_creds_b64}"}
    
    
    def get_token_data(self):
        return {"grant_type":"client_credentials"}
    
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if (r.status_code not in range(200,299)):
            raise Exception("Could not authenticate client.")
        token_response_data = r.json()
        now = datetime.datetime.now()
        access_token = token_response_data['access_token']
        expires_in = token_response_data['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now   
        return True
    
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if (expires < now):
            self.perform_auth()
            return self.get_access_token()
        elif (token == None):
            self.perform_auth()
            return self.get_access_token()            
        return token
    
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers
    
    
    def get_resource(self, lookup_id, resource_type="albums", version="v1"):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"       
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        print(endpoint)
        print(headers)
        print(r)
        if (r.status_code not in range(200,299)):
            return {}
        return r.json()
    
    
    def get_album(self, _id):
        return self.get_resource(_id, resource_type='albums')
        pass
        
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists')
        pass
    
    
    def search(self, query, search_type='artist'):
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        data = urlencode({"q": query,"type": search_type})
        lookup_url = f"{endpoint}?{data}"
        r = requests.get(url=lookup_url, headers=headers)    
        if (r.status_code not in range(200,299)):
            return {}
        return r.json()

# %%
CLIENT_ID = '2490920ce5574a1a9b97a3e366c39dd3'
CLIENT_SECRET = 'bfb4c438f0e742e3ab325f98a4b3b9dc'

spotify = SpotifyAPI(CLIENT_ID, CLIENT_SECRET)

# %%
spotify.search("Time", search_type="track")
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Time&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6fOMl44jA4Sp5b9PpYCkzz'},
#        'href': 'https://api.spotify.com/v1/artists/6fOMl44jA4Sp5b9PpYCkzz',
#        'id': '6fOMl44jA4Sp5b9PpYCkzz',
#        'name': 'NF',
#        'type': 'artist',
#        'uri': 'spotify:artist:6fOMl44jA4Sp5b9PpYCkzz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/46xdC4Qcvscfs3Ai2RIHcv'},
#      'href': 'https://api.spotify.com/v1/albums/46xdC4Qcvscfs3Ai2RIHcv',
#      'id': '46xdC4Qcvscfs3Ai2RIHcv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273942a0c9ac8f1def7c8805044',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02942a0c9ac8f1def7c8805044',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851942a0c9ac8f1def7c8805044',
#        'width': 64}],
#      'name': 'The Search',
#      'release_date': '2019-07-26',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:46xdC4Qcvscfs3Ai2RIHcv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6fOMl44jA4Sp5b9PpYCkzz'},
#       'href': 'https://api.spotify.com/v1/artists/6fOMl44jA4Sp5b9PpYCkzz',
#       'id': '6fOMl44jA4Sp5b9PpYCkzz',
#       'name': 'NF',
#       'type': 'artist',
#       'uri': 'spotify:artist:6fOMl44jA4Sp5b9PpYCkzz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 240428,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71910924'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6MxMqCgqmekcr0VwSU7AVH'},
#     'href': 'https://api.spotify.com/v1/tracks/6MxMqCgqmekcr0VwSU7AVH',
#     'id': '6MxMqCgqmekcr0VwSU7AVH',
#     'is_local': False,
#     'name': 'Time',
#     'popularity': 76,
#     'preview_url': None,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:6MxMqCgqmekcr0VwSU7AVH'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2EMAnMvWE2eb56ToJVfCWs'},
#        'href': 'https://api.spotify.com/v1/artists/2EMAnMvWE2eb56ToJVfCWs',
#        'id': '2EMAnMvWE2eb56ToJVfCWs',
#        'name': 'Bryson Tiller',
#        'type': 'artist',
#        'uri': 'spotify:artist:2EMAnMvWE2eb56ToJVfCWs'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5KpXxX7OUDXRs25qLyN8NA'},
#      'href': 'https://api.spotify.com/v1/albums/5KpXxX7OUDXRs25qLyN8NA',
#      'id': '5KpXxX7OUDXRs25qLyN8NA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273008d8077814ce15da0085b47',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02008d8077814ce15da0085b47',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851008d8077814ce15da0085b47',
#        'width': 64}],
#      'name': 'A N N I V E R S A R Y',
#      'release_date': '2020-10-02',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5KpXxX7OUDXRs25qLyN8NA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2EMAnMvWE2eb56ToJVfCWs'},
#       'href': 'https://api.spotify.com/v1/artists/2EMAnMvWE2eb56ToJVfCWs',
#       'id': '2EMAnMvWE2eb56ToJVfCWs',
#       'name': 'Bryson Tiller',
#       'type': 'artist',
#       'uri': 'spotify:artist:2EMAnMvWE2eb56ToJVfCWs'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 179188,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRC12003232'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6Iw6fQVKZi0fWtEQBrTFcP'},
#     'href': 'https://api.spotify.com/v1/tracks/6Iw6fQVKZi0fWtEQBrTFcP',
#     'id': '6Iw6fQVKZi0fWtEQBrTFcP',
#     'is_local': False,
#     'name': 'Timeless Interlude',
#     'popularity': 71,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7eab5b19bd793e22367b918e5b3c79780628872b?cid=2490920ce5574a1a9b97a3e366c39dd3',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:6Iw6fQVKZi0fWtEQBrTFcP'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#        'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#        'id': '3TVXtAsR1Inumwj472S9r4',
#        'name': 'Drake',
#        'type': 'artist',
#        'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6OQ9gBfg5EXeNAEwGSs6jK'},
#      'href': 'https://api.spotify.com/v1/albums/6OQ9gBfg5EXeNAEwGSs6jK',
#      'id': '6OQ9gBfg5EXeNAEwGSs6jK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bba7cfaf7c59ff0898acba1f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bba7cfaf7c59ff0898acba1f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bba7cfaf7c59ff0898acba1f',
#        'width': 64}],
#      'name': 'Dark Lane Demo Tapes',
#      'release_date': '2020-05-01',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:6OQ9gBfg5EXeNAEwGSs6jK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 192931,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG12001728'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5H4mXWKcicuLKDn4Jy0sK7'},
#     'href': 'https://api.spotify.com/v1/tracks/5H4mXWKcicuLKDn4Jy0sK7',
#     'id': '5H4mXWKcicuLKDn4Jy0sK7',
#     'is_local': False,
#     'name': 'Time Flies',
#     'popularity': 75,
#     'preview_url': None,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:5H4mXWKcicuLKDn4Jy0sK7'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TnOYISbd1XYRBk9myaseg'},
#        'href': 'https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg',
#        'id': '0TnOYISbd1XYRBk9myaseg',
#        'name': 'Pitbull',
#        'type': 'artist',
#        'uri': 'spotify:artist:0TnOYISbd1XYRBk9myaseg'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4EUf4YyNjuXypWY6W5wEDm'},
#      'href': 'https://api.spotify.com/v1/albums/4EUf4YyNjuXypWY6W5wEDm',
#      'id': '4EUf4YyNjuXypWY6W5wEDm',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731e340d1480e7bb29a45e3bd7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021e340d1480e7bb29a45e3bd7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511e340d1480e7bb29a45e3bd7',
#        'width': 64}],
#      'name': 'Globalization',
#      'release_date': '2014-11-21',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4EUf4YyNjuXypWY6W5wEDm'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TnOYISbd1XYRBk9myaseg'},
#       'href': 'https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg',
#       'id': '0TnOYISbd1XYRBk9myaseg',
#       'name': 'Pitbull',
#       'type': 'artist',
#       'uri': 'spotify:artist:0TnOYISbd1XYRBk9myaseg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/21E3waRsmPlU7jZsS13rcj'},
#       'href': 'https://api.spotify.com/v1/artists/21E3waRsmPlU7jZsS13rcj',
#       'id': '21E3waRsmPlU7jZsS13rcj',
#       'name': 'Ne-Yo',
#       'type': 'artist',
#       'uri': 'spotify:artist:21E3waRsmPlU7jZsS13rcj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 229360,
#     'explicit': True,
#     'external_ids': {'isrc': 'USRC11402647'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2bJvI42r8EF3wxjOuDav4r'},
#     'href': 'https://api.spotify.com/v1/tracks/2bJvI42r8EF3wxjOuDav4r',
#     'id': '2bJvI42r8EF3wxjOuDav4r',
#     'is_local': False,
#     'name': 'Time of Our Lives',
#     'popularity': 77,
#     'preview_url': 'https://p.scdn.co/mp3-preview/456046f512b8da97b84928f67cf9d8b2594db484?cid=2490920ce5574a1a9b97a3e366c39dd3',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2bJvI42r8EF3wxjOuDav4r'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0k17h0D3J5VfsdmQ1iZtE9'},
#        'href': 'https://api.spotify.com/v1/artists/0k17h0D3J5VfsdmQ1iZtE9',
#        'id': '0k17h0D3J5VfsdmQ1iZtE9',
#        'name': 'Pink Floyd',
#        'type': 'artist',
#        'uri': 'spotify:artist:0k17h0D3J5VfsdmQ1iZtE9'}],
#      'available_markets': ['AE',
#       'AR',
#       'AU',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'DO',
#       'EC',
#       'EG',
#       'GT',
#       'HK',
#       'HN',
#       'ID',
#       'IL',
#       'IN',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'MX',
#       'MY',
#       'NI',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PS',
#       'PY',
#       'QA',
#       'SA',
#       'SG',
#       'SV',
#       'TH',
#       'TN',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4LH4d3cOWNNsVw41Gqt2kv'},
#      'href': 'https://api.spotify.com/v1/albums/4LH4d3cOWNNsVw41Gqt2kv',
#      'id': '4LH4d3cOWNNsVw41Gqt2kv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f05e5ac32fdd79d100315a20',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f05e5ac32fdd79d100315a20',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f05e5ac32fdd79d100315a20',
#        'width': 64}],
#      'name': 'The Dark Side of the Moon',
#      'release_date': '1973-03-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:4LH4d3cOWNNsVw41Gqt2kv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0k17h0D3J5VfsdmQ1iZtE9'},
#       'href': 'https://api.spotify.com/v1/artists/0k17h0D3J5VfsdmQ1iZtE9',
#       'id': '0k17h0D3J5VfsdmQ1iZtE9',
#       'name': 'Pink Floyd',
#       'type': 'artist',
#       'uri': 'spotify:artist:0k17h0D3J5VfsdmQ1iZtE9'}],
#     'available_markets': ['AE',
#      'AR',
#      'AU',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'EC',
#      'EG',
#      'GT',
#      'HK',
#      'HN',
#      'ID',
#      'IL',
#      'IN',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'MX',
#      'MY',
#      'NI',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PS',
#      'PY',
#      'QA',
#      'SA',
#      'SG',
#      'SV',
#      'TH',
#      'TN',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 413947,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBN9Y1100079'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3TO7bbrUKrOSPGRTB5MeCz'},
#     'href': 'https://api.spotify.com/v1/tracks/3TO7bbrUKrOSPGRTB5MeCz',
#     'id': '3TO7bbrUKrOSPGRTB5MeCz',
#     'is_local': False,
#     'name': 'Time',
#     'popularity': 70,
#     'preview_url': 'https://p.scdn.co/mp3-preview/83c1f92586bfa2a326b3c7c69aeb9321007f5055?cid=2490920ce5574a1a9b97a3e366c39dd3',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:3TO7bbrUKrOSPGRTB5MeCz'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0SwO7SWeDHJijQ3XNS7xEE'},
#        'href': 'https://api.spotify.com/v1/artists/0SwO7SWeDHJijQ3XNS7xEE',
#        'id': '0SwO7SWeDHJijQ3XNS7xEE',
#        'name': 'MGMT',
#        'type': 'artist',
#        'uri': 'spotify:artist:0SwO7SWeDHJijQ3XNS7xEE'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6mm1Skz3JE6AXneya9Nyiv'},
#      'href': 'https://api.spotify.com/v1/albums/6mm1Skz3JE6AXneya9Nyiv',
#      'id': '6mm1Skz3JE6AXneya9Nyiv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738b32b139981e79f2ebe005eb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028b32b139981e79f2ebe005eb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518b32b139981e79f2ebe005eb',
#        'width': 64}],
#      'name': 'Oracular Spectacular',
#      'release_date': '2007-12-14',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:6mm1Skz3JE6AXneya9Nyiv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0SwO7SWeDHJijQ3XNS7xEE'},
#       'href': 'https://api.spotify.com/v1/artists/0SwO7SWeDHJijQ3XNS7xEE',
#       'id': '0SwO7SWeDHJijQ3XNS7xEE',
#       'name': 'MGMT',
#       'type': 'artist',
#       'uri': 'spotify:artist:0SwO7SWeDHJijQ3XNS7xEE'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 261000,
#     'explicit': True,
#     'external_ids': {'isrc': 'USSM10702127'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4iG2gAwKXsOcijVaVXzRPW'},
#     'href': 'https://api.spotify.com/v1/tracks/4iG2gAwKXsOcijVaVXzRPW',
#     'id': '4iG2gAwKXsOcijVaVXzRPW',
#     'is_local': False,
#     'name': 'Time to Pretend',
#     'popularity': 72,
#     'preview_url': 'https://p.scdn.co/mp3-preview/43cdff18bbe12ddd0a1ec829b87cf15b43a0a73f?cid=2490920ce5574a1a9b97a3e366c39dd3',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4iG2gAwKXsOcijVaVXzRPW'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YC192cP3KPCRWx8zr8MfZ'},
#        'href': 'https://api.spotify.com/v1/artists/0YC192cP3KPCRWx8zr8MfZ',
#        'id': '0YC192cP3KPCRWx8zr8MfZ',
#        'name': 'Hans Zimmer',
#        'type': 'artist',
#        'uri': 'spotify:artist:0YC192cP3KPCRWx8zr8MfZ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2qvA7HmSg1iM6XMiFF76dp'},
#      'href': 'https://api.spotify.com/v1/albums/2qvA7HmSg1iM6XMiFF76dp',
#      'id': '2qvA7HmSg1iM6XMiFF76dp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bb53ecc4d4e007f8c0464753',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bb53ecc4d4e007f8c0464753',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bb53ecc4d4e007f8c0464753',
#        'width': 64}],
#      'name': 'Inception (Music From The Motion Picture)',
#      'release_date': '2010-07-09',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2qvA7HmSg1iM6XMiFF76dp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YC192cP3KPCRWx8zr8MfZ'},
#       'href': 'https://api.spotify.com/v1/artists/0YC192cP3KPCRWx8zr8MfZ',
#       'id': '0YC192cP3KPCRWx8zr8MfZ',
#       'name': 'Hans Zimmer',
#       'type': 'artist',
#       'uri': 'spotify:artist:0YC192cP3KPCRWx8zr8MfZ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 275546,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRE11000577'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6ZFbXIJkuI1dVNWvzJzown'},
#     'href': 'https://api.spotify.com/v1/tracks/6ZFbXIJkuI1dVNWvzJzown',
#     'id': '6ZFbXIJkuI1dVNWvzJzown',
#     'is_local': False,
#     'name': 'Time',
#     'popularity': 72,
#     'preview_url': 'https://p.scdn.co/mp3-preview/eb463247243646de10aa4d9b3f2c0c8b836c1dc8?cid=2490920ce5574a1a9b97a3e366c39dd3',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:6ZFbXIJkuI1dVNWvzJzown'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2BQVRw9md4UKcGUrDXABCD'},
#        'href': 'https://api.spotify.com/v1/artists/2BQVRw9md4UKcGUrDXABCD',
#        'id': '2BQVRw9md4UKcGUrDXABCD',
#        'name': 'Tracy Lawrence',
#        'type': 'artist',
#        'uri': 'spotify:artist:2BQVRw9md4UKcGUrDXABCD'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5zSPDpefI09DHOSdQLJTW6'},
#      'href': 'https://api.spotify.com/v1/albums/5zSPDpefI09DHOSdQLJTW6',
#      'id': '5zSPDpefI09DHOSdQLJTW6',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733eac04f4db8c45984d4edb0c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023eac04f4db8c45984d4edb0c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513eac04f4db8c45984d4edb0c',
#        'width': 64}],
#      'name': 'Time Marches On',
#      'release_date': '1996-01-02',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5zSPDpefI09DHOSdQLJTW6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2BQVRw9md4UKcGUrDXABCD'},
#       'href': 'https://api.spotify.com/v1/artists/2BQVRw9md4UKcGUrDXABCD',
#       'id': '2BQVRw9md4UKcGUrDXABCD',
#       'name': 'Tracy Lawrence',
#       'type': 'artist',
#       'uri': 'spotify:artist:2BQVRw9md4UKcGUrDXABCD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 185360,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAN19600003'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2TIEeLrOQrGnO2D2OeDDJu'},
#     'href': 'https://api.spotify.com/v1/tracks/2TIEeLrOQrGnO2D2OeDDJu',
#     'id': '2TIEeLrOQrGnO2D2OeDDJu',
#     'is_local': False,
#     'name': 'Time Marches On',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e4ae2d412a423566fa2c7f903f3f35aa7e1bf9c2?cid=2490920ce5574a1a9b97a3e366c39dd3',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2TIEeLrOQrGnO2D2OeDDJu'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1gPhS1zisyXr5dHTYZyiMe'},
#        'href': 'https://api.spotify.com/v1/artists/1gPhS1zisyXr5dHTYZyiMe',
#        'id': '1gPhS1zisyXr5dHTYZyiMe',
#        'name': 'Kevin Gates',
#        'type': 'artist',
#        'uri': 'spotify:artist:1gPhS1zisyXr5dHTYZyiMe'}],
#      'available_markets': ['AD',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KW',
#       'KZ',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'RO',
#       'RS',
#       'RU',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5Hs43ta4vAYKRRRR7DKjt9'},
#      'href': 'https://api.spotify.com/v1/albums/5Hs43ta4vAYKRRRR7DKjt9',
#      'id': '5Hs43ta4vAYKRRRR7DKjt9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739b78cdf77301fc50d06423b3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029b78cdf77301fc50d06423b3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519b78cdf77301fc50d06423b3',
#        'width': 64}],
#      'name': 'Islah (Deluxe)',
#      'release_date': '2016-01-29',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:5Hs43ta4vAYKRRRR7DKjt9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1gPhS1zisyXr5dHTYZyiMe'},
#       'href': 'https://api.spotify.com/v1/artists/1gPhS1zisyXr5dHTYZyiMe',
#       'id': '1gPhS1zisyXr5dHTYZyiMe',
#       'name': 'Kevin Gates',
#       'type': 'artist',
#       'uri': 'spotify:artist:1gPhS1zisyXr5dHTYZyiMe'}],
#     'available_markets': ['AD',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KW',
#      'KZ',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'RS',
#      'RU',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 208440,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT21503160'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1gZNqH0rDxD1mXLeul1Qq7'},
#     'href': 'https://api.spotify.com/v1/tracks/1gZNqH0rDxD1mXLeul1Qq7',
#     'id': '1gZNqH0rDxD1mXLeul1Qq7',
#     'is_local': False,
#     'name': 'Time for That',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7ecf75b2fec6dfb4d787b3865bf3ebfd6f03cb8e?cid=2490920ce5574a1a9b97a3e366c39dd3',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:1gZNqH0rDxD1mXLeul1Qq7'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4596e2d3KmYzAeVenjCxfj'},
#        'href': 'https://api.spotify.com/v1/artists/4596e2d3KmYzAeVenjCxfj',
#        'id': '4596e2d3KmYzAeVenjCxfj',
#        'name': 'Free Nationals',
#        'type': 'artist',
#        'uri': 'spotify:artist:4596e2d3KmYzAeVenjCxfj'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LLpKhyESsyAXpc4laK94U'},
#        'href': 'https://api.spotify.com/v1/artists/4LLpKhyESsyAXpc4laK94U',
#        'id': '4LLpKhyESsyAXpc4laK94U',
#        'name': 'Mac Miller',
#        'type': 'artist',
#        'uri': 'spotify:artist:4LLpKhyESsyAXpc4laK94U'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1U1el3k54VvEUzo3ybLPlM'},
#        'href': 'https://api.spotify.com/v1/artists/1U1el3k54VvEUzo3ybLPlM',
#        'id': '1U1el3k54VvEUzo3ybLPlM',
#        'name': 'Kali Uchis',
#        'type': 'artist',
#        'uri': 'spotify:artist:1U1el3k54VvEUzo3ybLPlM'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5SEQL40XcXX1FUHtiqa8PG'},
#      'href': 'https://api.spotify.com/v1/albums/5SEQL40XcXX1FUHtiqa8PG',
#      'id': '5SEQL40XcXX1FUHtiqa8PG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e77470216cd52f05b9cd42a3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e77470216cd52f05b9cd42a3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e77470216cd52f05b9cd42a3',
#        'width': 64}],
#      'name': 'Time',
#      'release_date': '2019-06-12',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5SEQL40XcXX1FUHtiqa8PG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4596e2d3KmYzAeVenjCxfj'},
#       'href': 'https://api.spotify.com/v1/artists/4596e2d3KmYzAeVenjCxfj',
#       'id': '4596e2d3KmYzAeVenjCxfj',
#       'name': 'Free Nationals',
#       'type': 'artist',
#       'uri': 'spotify:artist:4596e2d3KmYzAeVenjCxfj'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LLpKhyESsyAXpc4laK94U'},
#       'href': 'https://api.spotify.com/v1/artists/4LLpKhyESsyAXpc4laK94U',
#       'id': '4LLpKhyESsyAXpc4laK94U',
#       'name': 'Mac Miller',
#       'type': 'artist',
#       'uri': 'spotify:artist:4LLpKhyESsyAXpc4laK94U'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1U1el3k54VvEUzo3ybLPlM'},
#       'href': 'https://api.spotify.com/v1/artists/1U1el3k54VvEUzo3ybLPlM',
#       'id': '1U1el3k54VvEUzo3ybLPlM',
#       'name': 'Kali Uchis',
#       'type': 'artist',
#       'uri': 'spotify:artist:1U1el3k54VvEUzo3ybLPlM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 210279,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUYG1258274'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/05v5mPkLAOoa7M5tnXXOwq'},
#     'href': 'https://api.spotify.com/v1/tracks/05v5mPkLAOoa7M5tnXXOwq',
#     'id': '05v5mPkLAOoa7M5tnXXOwq',
#     'is_local': False,
#     'name': 'Time',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a95845690d556b59044e35f73985e5a6766029d3?cid=2490920ce5574a1a9b97a3e366c39dd3',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:05v5mPkLAOoa7M5tnXXOwq'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2BTZIqw0ntH9MvilQ3ewNY'},
#        'href': 'https://api.spotify.com/v1/artists/2BTZIqw0ntH9MvilQ3ewNY',
#        'id': '2BTZIqw0ntH9MvilQ3ewNY',
#        'name': 'Cyndi Lauper',
#        'type': 'artist',
#        'uri': 'spotify:artist:2BTZIqw0ntH9MvilQ3ewNY'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1FvdZ1oizXwF9bxogujoF0'},
#      'href': 'https://api.spotify.com/v1/albums/1FvdZ1oizXwF9bxogujoF0',
#      'id': '1FvdZ1oizXwF9bxogujoF0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27352f532df7ba3269b0242fed9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0252f532df7ba3269b0242fed9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485152f532df7ba3269b0242fed9',
#        'width': 64}],
#      'name': "She's So Unusual",
#      'release_date': '1983-10-14',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1FvdZ1oizXwF9bxogujoF0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2BTZIqw0ntH9MvilQ3ewNY'},
#       'href': 'https://api.spotify.com/v1/artists/2BTZIqw0ntH9MvilQ3ewNY',
#       'id': '2BTZIqw0ntH9MvilQ3ewNY',
#       'name': 'Cyndi Lauper',
#       'type': 'artist',
#       'uri': 'spotify:artist:2BTZIqw0ntH9MvilQ3ewNY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 241333,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM18300650'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7o9uu2GDtVDr9nsR7ZRN73'},
#     'href': 'https://api.spotify.com/v1/tracks/7o9uu2GDtVDr9nsR7ZRN73',
#     'id': '7o9uu2GDtVDr9nsR7ZRN73',
#     'is_local': False,
#     'name': 'Time After Time',
#     'popularity': 72,
#     'preview_url': 'https://p.scdn.co/mp3-preview/53a84502abfa84f3fa72eddc4da3f65e4a4af903?cid=2490920ce5574a1a9b97a3e366c39dd3',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:7o9uu2GDtVDr9nsR7ZRN73'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0c173mlxpT3dSFRgMO8XPh'},
#        'href': 'https://api.spotify.com/v1/artists/0c173mlxpT3dSFRgMO8XPh',
#        'id': '0c173mlxpT3dSFRgMO8XPh',
#        'name': 'Big Sean',
#        'type': 'artist',
#        'uri': 'spotify:artist:0c173mlxpT3dSFRgMO8XPh'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
# ...
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 186373,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10600165'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7piw04hPQZ1OHZ9Fq9JOXR'},
#     'href': 'https://api.spotify.com/v1/tracks/7piw04hPQZ1OHZ9Fq9JOXR',
#     'id': '7piw04hPQZ1OHZ9Fq9JOXR',
#     'is_local': False,
#     'name': 'Time of Dying',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d2da079180cf8de8d90982c820de59c15fe207ee?cid=2490920ce5574a1a9b97a3e366c39dd3',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:7piw04hPQZ1OHZ9Fq9JOXR'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55vs7NT1KxcFjbMC4y202E'},
#        'href': 'https://api.spotify.com/v1/artists/55vs7NT1KxcFjbMC4y202E',
#        'id': '55vs7NT1KxcFjbMC4y202E',
#        'name': 'REO Speedwagon',
#        'type': 'artist',
#        'uri': 'spotify:artist:55vs7NT1KxcFjbMC4y202E'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3w0BIqN0uMoOT2l2ppKuXx'},
#      'href': 'https://api.spotify.com/v1/albums/3w0BIqN0uMoOT2l2ppKuXx',
#      'id': '3w0BIqN0uMoOT2l2ppKuXx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27340c8a6ff21a1d52575185f38',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0240c8a6ff21a1d52575185f38',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485140c8a6ff21a1d52575185f38',
#        'width': 64}],
#      'name': "You Can Tune a Piano, But You Can't Tuna Fish",
#      'release_date': '1978-03-16',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:3w0BIqN0uMoOT2l2ppKuXx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55vs7NT1KxcFjbMC4y202E'},
#       'href': 'https://api.spotify.com/v1/artists/55vs7NT1KxcFjbMC4y202E',
#       'id': '55vs7NT1KxcFjbMC4y202E',
#       'name': 'REO Speedwagon',
#       'type': 'artist',
#       'uri': 'spotify:artist:55vs7NT1KxcFjbMC4y202E'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 221386,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10012771'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0cO7JEo8deKuQMWpDyjenY'},
#     'href': 'https://api.spotify.com/v1/tracks/0cO7JEo8deKuQMWpDyjenY',
#     'id': '0cO7JEo8deKuQMWpDyjenY',
#     'is_local': False,
#     'name': 'Time for Me to Fly - As heard in the Netflix series Ozark',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/04d22e53827fa8db1441f4f80208a14bc8bb5e4d?cid=2490920ce5574a1a9b97a3e366c39dd3',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:0cO7JEo8deKuQMWpDyjenY'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1R6Hx1tJ2VOUyodEpC12xM'},
#        'href': 'https://api.spotify.com/v1/artists/1R6Hx1tJ2VOUyodEpC12xM',
#        'id': '1R6Hx1tJ2VOUyodEpC12xM',
#        'name': 'Jim Croce',
#        'type': 'artist',
#        'uri': 'spotify:artist:1R6Hx1tJ2VOUyodEpC12xM'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3L9sVl5T7UpFK6tNeEiXdy'},
#      'href': 'https://api.spotify.com/v1/albums/3L9sVl5T7UpFK6tNeEiXdy',
#      'id': '3L9sVl5T7UpFK6tNeEiXdy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27398078d325c25a5ac4081cfba',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0298078d325c25a5ac4081cfba',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485198078d325c25a5ac4081cfba',
#        'width': 64}],
#      'name': "You Don't Mess Around With Jim",
#      'release_date': '1972-04-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3L9sVl5T7UpFK6tNeEiXdy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1R6Hx1tJ2VOUyodEpC12xM'},
#       'href': 'https://api.spotify.com/v1/artists/1R6Hx1tJ2VOUyodEpC12xM',
#       'id': '1R6Hx1tJ2VOUyodEpC12xM',
#       'name': 'Jim Croce',
#       'type': 'artist',
#       'uri': 'spotify:artist:1R6Hx1tJ2VOUyodEpC12xM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 146175,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAJE7200780'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/561F1zqRwGPCTMRsLsXVtL'},
#     'href': 'https://api.spotify.com/v1/tracks/561F1zqRwGPCTMRsLsXVtL',
#     'id': '561F1zqRwGPCTMRsLsXVtL',
#     'is_local': False,
#     'name': 'Time In a Bottle',
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/81da62da84116af30a16c958f4c95e522fc0d147?cid=2490920ce5574a1a9b97a3e366c39dd3',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:561F1zqRwGPCTMRsLsXVtL'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SlWk9stVDNIL6l4BK2MlI'},
#        'href': 'https://api.spotify.com/v1/artists/4SlWk9stVDNIL6l4BK2MlI',
#        'id': '4SlWk9stVDNIL6l4BK2MlI',
#        'name': 'Danielle Fleur',
#        'type': 'artist',
#        'uri': 'spotify:artist:4SlWk9stVDNIL6l4BK2MlI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7c9zTWwG3gmkYRqWomwQ6Q'},
#      'href': 'https://api.spotify.com/v1/albums/7c9zTWwG3gmkYRqWomwQ6Q',
#      'id': '7c9zTWwG3gmkYRqWomwQ6Q',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731690615203568b7a755edab1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021690615203568b7a755edab1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511690615203568b7a755edab1',
#        'width': 64}],
#      'name': 'Time is the Longest Distance',
#      'release_date': '2020-06-26',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7c9zTWwG3gmkYRqWomwQ6Q'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SlWk9stVDNIL6l4BK2MlI'},
#       'href': 'https://api.spotify.com/v1/artists/4SlWk9stVDNIL6l4BK2MlI',
#       'id': '4SlWk9stVDNIL6l4BK2MlI',
#       'name': 'Danielle Fleur',
#       'type': 'artist',
#       'uri': 'spotify:artist:4SlWk9stVDNIL6l4BK2MlI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 124452,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5IB2001149'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1vViUoB7DpXUX10isPj7YL'},
#     'href': 'https://api.spotify.com/v1/tracks/1vViUoB7DpXUX10isPj7YL',
#     'id': '1vViUoB7DpXUX10isPj7YL',
#     'is_local': False,
#     'name': 'Time is the Longest Distance',
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/eb4ca522f1ca9f64dac200b1d92c6196309d6dbd?cid=2490920ce5574a1a9b97a3e366c39dd3',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1vViUoB7DpXUX10isPj7YL'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0q9lPhJHW5R9J7RXIJRbTk'},
#        'href': 'https://api.spotify.com/v1/artists/0q9lPhJHW5R9J7RXIJRbTk',
#        'id': '0q9lPhJHW5R9J7RXIJRbTk',
#        'name': 'Iration',
#        'type': 'artist',
#        'uri': 'spotify:artist:0q9lPhJHW5R9J7RXIJRbTk'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2cj7tjVe3FsSfTZCKk1jNk'},
#      'href': 'https://api.spotify.com/v1/albums/2cj7tjVe3FsSfTZCKk1jNk',
#      'id': '2cj7tjVe3FsSfTZCKk1jNk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273507687db42c3a9ac52d6ff8c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02507687db42c3a9ac52d6ff8c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851507687db42c3a9ac52d6ff8c',
#        'width': 64}],
#      'name': 'Time Bomb',
#      'release_date': '2010-03-16',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:2cj7tjVe3FsSfTZCKk1jNk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0q9lPhJHW5R9J7RXIJRbTk'},
#       'href': 'https://api.spotify.com/v1/artists/0q9lPhJHW5R9J7RXIJRbTk',
#       'id': '0q9lPhJHW5R9J7RXIJRbTk',
#       'name': 'Iration',
#       'type': 'artist',
#       'uri': 'spotify:artist:0q9lPhJHW5R9J7RXIJRbTk'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 190693,
#     'explicit': False,
#     'external_ids': {'isrc': 'USME30902987'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0KtKac3tvjeGjg6FXcUy7X'},
#     'href': 'https://api.spotify.com/v1/tracks/0KtKac3tvjeGjg6FXcUy7X',
#     'id': '0KtKac3tvjeGjg6FXcUy7X',
#     'is_local': False,
#     'name': 'Time Bomb',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a9851a7507d5530e960b8781fa19471cb2e35ace?cid=2490920ce5574a1a9b97a3e366c39dd3',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0KtKac3tvjeGjg6FXcUy7X'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Time&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 100016}}

# %%
spotify.get_artist('6fOMl44jA4Sp5b9PpYCkzz')
# Out:
# https://api.spotify.com/v1/artists/6fOMl44jA4Sp5b9PpYCkzz
# {'Authorization': 'Bearer BQA5cpSnJmekVOwkg_7jLyoHWVENrQPzziW-2S8FR98RdLaTq5rple6MNTLEzZbdezC7r6LdhmvJQ6mpttM'}
# <Response [200]>
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/6fOMl44jA4Sp5b9PpYCkzz'},
#  'followers': {'href': None, 'total': 4281396},
#  'genres': ['hip hop', 'pop rap', 'rap'],
#  'href': 'https://api.spotify.com/v1/artists/6fOMl44jA4Sp5b9PpYCkzz',
#  'id': '6fOMl44jA4Sp5b9PpYCkzz',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/55db20d7c49bdcf52162474265c66ca601054b1c',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/cac511faa02c9257d5a3317d6df4dfb52ca19b5b',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/9f6f0a7a4839971f76831b297875a4435e25a3d1',
#    'width': 160}],
#  'name': 'NF',
#  'popularity': 86,
#  'type': 'artist',
#  'uri': 'spotify:artist:6fOMl44jA4Sp5b9PpYCkzz'}
